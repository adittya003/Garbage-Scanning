# %%
from zipfile import ZipFile

# %%
zip_file_path = '/content/drive/MyDrive/projects/Garbage_scanning/5class_gaarbage_classifier/mobilenet/garbage.zip'

# Use the !unzip shell command to extract the contents
# !unzip -q "$zip_file_path" -d /content/drive/MyDrive/projects/Garbage_scanning/5class_gaarbage_classifier/mobilenet/data
